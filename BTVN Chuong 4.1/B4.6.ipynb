# %%
import pandas as pd
import numpy as np

ser = pd.Series(np.take(list("abcdefgh"), np.random.randint(8, size=30)))

print("Giá trị xuất hiện nhiều nhất:")
print(ser.mode())

print("\nSố lần xuất hiện:")
print(ser.value_counts())
# Out:
# Giá trị xuất hiện nhiều nhất:
# 0    a
# dtype: object
#
# Số lần xuất hiện:
# a    6
# e    5
# b    5
# f    3
# h    3
# d    3
# c    3
# g    2
# Name: count, dtype: int64
