# %%
import pandas as pd
import numpy as np

ser = pd.Series(np.random.randn(200))

bins = pd.qcut(ser, 10)
print(bins.value_counts())
# Out:
# (-3.3209999999999997, -1.204]    20
# (-1.204, -0.738]                 20
# (-0.738, -0.383]                 20
# (-0.383, -0.198]                 20
# (-0.198, 0.0139]                 20
# (0.0139, 0.206]                  20
# (0.206, 0.503]                   20
# (0.503, 0.783]                   20
# (0.783, 1.159]                   20
# (1.159, 2.27]                    20
# Name: count, dtype: int64
