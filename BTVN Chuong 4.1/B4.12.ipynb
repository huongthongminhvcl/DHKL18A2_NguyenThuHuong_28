# %%
import pandas as pd

ser1 = pd.Series(range(5))
ser2 = pd.Series(list("abcde"))

df = pd.concat([ser1, ser2], axis=1)
print(df)
# Out:
#    0  1
# 0  0  a
# 1  1  b
# 2  2  c
# 3  3  d
# 4  4  e
