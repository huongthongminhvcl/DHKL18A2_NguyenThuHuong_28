# %%
import pandas as pd

ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])

result1 = ser1[~ser1.isin(ser2)]
result2 = ser1[~ser1.isin(ser2)]

print("Câu 1 – Xóa các mục có trong ser2:")
print(result1)

print("\nCâu 2 – Các mục chỉ có trong ser1:")
print(result2)
# Out:
# Câu 1 – Xóa các mục có trong ser2:
# 0    1
# 1    2
# 2    3
# dtype: int64
#
# Câu 2 – Các mục chỉ có trong ser1:
# 0    1
# 1    2
# 2    3
# dtype: int64
