# %%
import pandas as pd

ser1 = pd.Series([10, 9, 6, 5, 3, 1, 12, 8, 13])
ser2 = pd.Series([1, 3, 10, 13])

print("Các phần tử ser1 có trong ser2:")
print(ser1[ser1.isin(ser2)])
# Out:
# Các phần tử ser1 có trong ser2:
# 0    10
# 4     3
# 5     1
# 8    13
# dtype: int64
