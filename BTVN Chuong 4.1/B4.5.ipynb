# %%
import pandas as pd
import numpy as np

ser = pd.Series(np.random.normal(10, 5, 25))

print("Min:", ser.min())
print("25%:", ser.quantile(0.25))
print("Median:", ser.median())
print("75%:", ser.quantile(0.75))
print("Max:", ser.max())
# Out:
# Min: 3.799193372611893
# 25%: 7.662320037227704
# Median: 12.068552428821718
# 75%: 13.56048952047919
# Max: 24.796476054701785
