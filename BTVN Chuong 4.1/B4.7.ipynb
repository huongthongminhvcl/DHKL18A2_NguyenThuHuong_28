# %%
import pandas as pd
import numpy as np

np.random.seed(100)
ser = pd.Series(np.random.randint(1, 5, 12))

print("2 giá trị xuất hiện nhiều nhất:")
print(ser.value_counts().head(2))
# Out:
# 2 giá trị xuất hiện nhiều nhất:
# 1    4
# 4    4
# Name: count, dtype: int64
