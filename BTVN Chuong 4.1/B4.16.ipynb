# %%
import pandas as pd

ser = pd.Series([1, 3, 6, 10, 15, 21, 27, 35])
print("Hiệu giữa các phần tử liên tiếp:")
print(ser.diff())
# Out:
# Hiệu giữa các phần tử liên tiếp:
# 0    NaN
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    6.0
# 7    8.0
# dtype: float64
