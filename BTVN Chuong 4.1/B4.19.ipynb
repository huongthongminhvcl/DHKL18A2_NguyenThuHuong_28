# %%
import pandas as pd
import numpy as np

fruit = pd.Series(np.random.choice(["apple", "banana", "carrot"], 10))
weights = pd.Series(np.linspace(1, 10, 10))

print("Tổng trọng lượng theo loại quả:")
print(weights.groupby(fruit).sum())
# Out:
# Tổng trọng lượng theo loại quả:
# apple     14.0
# banana    10.0
# carrot    31.0
# dtype: float64
