# %%
import pandas as pd
import numpy as np

ser = pd.Series(np.random.randint(1, 10, 35))

print("Các phần tử lớn hơn trung bình:")
print(ser[ser > ser.mean()])
# Out:
# Các phần tử lớn hơn trung bình:
# 0     9
# 1     9
# 4     8
# 6     8
# 11    9
# 12    9
# 13    9
# 15    9
# 16    8
# 18    7
# 19    6
# 27    8
# 28    8
# 29    9
# 31    7
# 32    9
# 33    7
# dtype: int32
