# %%
import pandas as pd
import numpy as np

ser = pd.Series(np.random.randint(10, 70, 10))

print("Các bội số của 3:")
print(ser[ser % 3 == 0])
# Out:
# Các bội số của 3:
# 3    39
# 6    33
# 7    21
# 8    63
# dtype: int32
