# %%
# Xây dựng lớp ngăn xếp (Stack) gồm có:
# Dữ liệu là mảng float được cấp phát động.
# Hàm tạo, hàm huỷ và các phương thức:
# push: đưa một phần tử vào ngăn xếp.
# pop: lấy một phần tử ra từ đỉnh ngăn xếp.
# isEmpty: kiểm tra ngăn xếp đã trống chưa.
# isFull: kiểm tra ngăn xếp đã đầy chưa.

class Stack:
    def __init__(self, capacity):
        self.capacity = capacity       
        self.arr = [0.0] * capacity     
        self.top = -1                  

    def isEmpty(self):
        if self.top == -1:
            print("Stack is empty")
        else:
            print("Stack is not empty")

    def isFull(self):
        if self.top == self.capacity - 1:
            print("Stack is full")
        else:
            print("Stack is not full")

    def push(self, value: float):
        if self.top == self.capacity - 1:
            print(f"Stack is full. Cannot push {value}")
        else:
            self.top += 1
            self.arr[self.top] = float(value)
            print(f"Pushed {value} into stack")

    def pop(self):
        if self.top == -1:
            print("Stack is empty. Cannot pop.")
        else:
            value = self.arr[self.top]
            print(f"Popped {value} from stack")
            self.top -= 1

    def peek(self):
        if self.top == -1:
            print("Stack is empty.")
        else:
            print(f"Top element is {self.arr[self.top]}")


if __name__ == "__main__":
    s = Stack(5)

    s.push(1.1)
    s.push(2.2)
    s.push(3.3)

    s.peek()

    s.pop()
    s.pop()

    s.isEmpty()
# Out:
# Pushed 1.1 into stack
# Pushed 2.2 into stack
# Pushed 3.3 into stack
# Top element is 3.3
# Popped 3.3 from stack
# Popped 2.2 from stack
# Stack is not empty
