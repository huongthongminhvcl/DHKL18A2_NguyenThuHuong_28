# %% [markdown]
# 1. Khái niệm XML là gì?
#
# XML (Extensible Markup Language) là ngôn ngữ đánh dấu mở rộng được dùng để lưu trữ và trao đổi dữ liệu.
#
# Nó mô tả dữ liệu bằng các thẻ do người dùng định nghĩa.
#
# XML có cấu trúc cây và dễ dàng chia sẻ dữ liệu giữa các hệ thống khác nhau.
#
# 👉 Ví dụ:
#
# <student>
#     <name>Nguyen Van A</name>
#     <age>20</age>
# </student>
#
# 2. Khái niệm DOM?
#
# DOM (Document Object Model) là mô hình đối tượng tài liệu, biểu diễn cấu trúc của tài liệu XML hoặc HTML dưới dạng cây các nút (node tree).
#
# Mỗi phần tử, thuộc tính hoặc đoạn văn bản trong XML được xem là một nút trong cây DOM.
#
# DOM cho phép lập trình viên truy cập, thay đổi, thêm hoặc xóa các phần tử của tài liệu XML/HTML.
#
# 3. Cú pháp tài liệu XML?
#
# Một tài liệu XML hợp lệ cần tuân theo cú pháp sau:
#
# Có dòng khai báo XML:
#
# <?xml version="1.0" encoding="UTF-8"?>
#
#
# Có một phần tử gốc duy nhất (root element).
#
# Các thẻ phải được đóng đầy đủ.
#
# XML phân biệt chữ hoa chữ thường.
#
# Các thuộc tính phải có giá trị đặt trong dấu ngoặc kép.
#
# 4. Khái niệm JSON?
#
# JSON (JavaScript Object Notation) là định dạng trao đổi dữ liệu nhẹ, dễ đọc và dễ phân tích.
#
# Dữ liệu được lưu dưới dạng cặp key–value.
#
# JSON được dùng phổ biến trong giao tiếp giữa client và server.
#
# 👉 Ví dụ:
#
# {
#   "name": "Nguyen Van A",
#   "age": 20
# }
#
# 5. Hạn chế của việc triển khai JSON trong Python?
#
# Một số hạn chế:
#
# JSON chỉ hỗ trợ các kiểu dữ liệu cơ bản (string, number, boolean, array, object), không hỗ trợ kiểu dữ liệu phức tạp như set, tuple.
#
# Không thể lưu các đối tượng Python tùy chỉnh (custom class) trực tiếp mà phải chuyển đổi sang dict.
#
# Không hỗ trợ chú thích (comment) trong dữ liệu.
#
# 6. API XML là gì?
#
# API XML là giao diện lập trình ứng dụng cho phép thao tác, đọc, ghi hoặc phân tích tài liệu XML.
# Trong Python, có thể sử dụng các API như:
#
# xml.dom – xử lý theo mô hình DOM.
#
# xml.sax – xử lý theo mô hình sự kiện (event-driven).
#
# xml.etree.ElementTree – mô hình cây đơn giản, dễ dùng.
#
# 7. API JSON là gì?
#
# API JSON là giao diện lập trình cho phép mã hóa và giải mã dữ liệu JSON trong các ngôn ngữ lập trình.
# Trong Python, thư viện json được dùng để:
#
# json.dumps() – chuyển đối tượng Python sang chuỗi JSON.
#
# json.loads() – chuyển chuỗi JSON thành đối tượng Python.
#
# 8. Để phân tích tập tin XML có thể sử dụng các thư viện nào trong Python?
#
# Một số thư viện phổ biến:
#
# xml.etree.ElementTree
#
# xml.dom.minidom
#
# xml.sax
#
# lxml (thư viện mở rộng, mạnh mẽ và nhanh hơn thư viện chuẩn)
