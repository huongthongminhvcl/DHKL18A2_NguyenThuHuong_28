# %%
## Hiển thị phiên bản NumPy và nơi cài đặt

import numpy as np

print("Phiên bản NumPy:", np.__version__)
print("Đường dẫn cài đặt:", np.__file__)
# Out:
# Phiên bản NumPy: 2.3.4
# Đường dẫn cài đặt: c:\Users\ADMINPG\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\__init__.py
