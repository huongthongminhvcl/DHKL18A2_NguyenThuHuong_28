# %%
import numpy as np

# %%
np_baseball = np.array(baseball)
print(np_baseball.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np_baseball = np.array(baseball)
#       2 print(np_baseball.shape)
#
# NameError: name 'baseball' is not defined

# %%
print(np_baseball[49, 1])

# %%
height = np_baseball[:, 0]
weight = np_baseball[:, 1]

# %%
print(np_baseball[124])

# %%
print(height.mean(), weight.mean())

# %%
corr = np.corrcoef(height, weight)
print(corr)
