# %%
## (MLB – Chiều cao & cân nặng)

import numpy as np

# %%
## 1-2 Đọc dữ liệu (giả sử đã copy vào list)

height = [...]   # inch
weight = [...]   # pound

arr_height = np.array(height)
arr_weight = np.array(weight)

# %%
## 3. Inch sang mét

arr_height_m = arr_height * 0.0254
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 ## 3. Inch sang mét
# ----> 3 arr_height_m = arr_height * 0.0254
#
# TypeError: unsupported operand type(s) for *: 'ellipsis' and 'float'

# %%
## 4. Pound sang kg

arr_weight_kg = arr_weight * 0.453592

# %%
## 5. BMI

bmi = arr_weight_kg / (arr_height_m ** 2)

# %%
# 6. Giá trị cân nặng index 50 đến 70

print(arr_weight_kg[50:71])

# %%
## 7. Chiều cao index 100 đến 110

print(arr_height_m[100:111])

# %%
## 8. Số cầu thủ có BMI < 21

print(np.sum(bmi < 21))

# %%
## 9. Chiều cao & cân nặng trung bình

print(arr_height_m.mean(), arr_weight_kg.mean())

# %%
## 10. Cao và nặng nhất

print(arr_height_m.max(), arr_weight_kg.max())

# %%
## 11. Cao & nhẹ nhất

print(arr_height_m.min(), arr_weight_kg.min())
